# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
X = pd.DataFrame(iris.data, columns = ['Sepal Length','Sepal Width','Petal Length','Petal Width']) # Name columns according to data set
X.corr(method = "pearson")
# This will display a 4 x 4 DataFrame displaying the correlations between the row and column variable. What values of
# the correlation coefficients will be along the main diagonal?
# Out:
#               Sepal Length  Sepal Width  Petal Length  Petal Width
# Sepal Length      1.000000    -0.117570      0.871754     0.817941
# Sepal Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal Length      0.871754    -0.428440      1.000000     0.962865
# Petal Width       0.817941    -0.366126      0.962865     1.000000

# %%
corr_feature = # Petal Dimensions
target = X['Sepal Length']

feature_train, feature_test, target_train, target_test = train_test_split(_____,target,test_size = 0.2, random_state=42) # only look at Petal Length
corr_feature_train, corr_feature_test, corr_target_train, corr_target_test = train_test_split(_____,target,test_size = 0.2, random_state=42) # look at both Petal Length and Width

# %%
from sklearn.linear_model import LinearRegression

# Instantiate
uncorr_model = # FILL
corr_model = # FILL

uncorr_model.fit(_____, _____)
corr_model.fit(_____, _____)
# Out:
# LinearRegression()

# %%
print('Uncorrelated training score: ', uncorr_model.score(_____, _____))
print('Uncorrelated testing score: ', uncorr_model.score(_____, _____))
# Out:
# Uncorrelated training score:  0.7433457054705969
# Uncorrelated testing score:  0.812980761507489

# %%
print('Correlated training score: ', corr_model.score(_____, _____))
print('Correlated testing score: ', corr_model.score(_____, _____))
# Out:
# Correlated training score:  0.7543504893573446
# Correlated testing score:  0.7972490195696221
